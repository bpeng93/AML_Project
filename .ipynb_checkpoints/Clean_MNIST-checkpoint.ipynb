# %% [markdown]
# ## <font color='red'> Here are the notations we will use: </font>
#
# #**Main Title** (such as Feature Visulization For MNIST)
#
# Introduction to this topic
#
# ##**Sub Title** (main step)
#
# introduction to this step. If no, just leave it as blank.
#
# ###**(1) Detailed step title**
#
# **Function defination format:** (for some important functions)
# ```{python}
# def temp_func(a,b):
#     '''
#     This function aims to show how to write the help file for this function.
#
#     Parameter
#     ---------
#     a: A numpy array that contains the image information
#     b: A pandas dataframe that contains the ...
#
#     Return
#     ------
#     c: A numpy array ...
#     '''
#
#     a = b
#     ...
#
#     return(c)
#
# ```
#
# **Function defination format** (for some simple functions)
# ```{python}
# # This function aims to find the ...
# def find_func(a,b):
#     a = b
#     ...
#     return(c)
# ```

# %% [markdown]
# # GR5242 Final Project: Feature Visualization for CNN
# #### Team Member： Jielai Sheng, Yingbin Jiang, Bo Peng, Fan Gong
#
# ## 1. Introduction
# Large Convolutional Network models have recently demonstrated impressive classification performance on the ImageNet benchmark. However there is no clear understanding of why they perform so well, or how they might be improved. So here comes feature visualization. In this project, we try to use two different methods and three different CNN model to get the insight about what is really going on in each of the layer and how CNN could get such a good result. Here are the brief summaries about our models and methods:
#
# * **MINIST Dataset** (Six layers convolutional neural networks + two feature visualization mathods)
# * **SVHN Dataset** (Six layers convolutional neural networks + one feature visualization mathods)
# * **Cifar10 Dataset** (Six layers convolutional neural networks + two feature visualization methods)
#
# ## 2. Feature Visualization Methods
# We use two different ways to visualize the feature in each layer. The first method is called unpooling and deconvolution; the second method is called feature maximization.
#
# ### (1) Deconvolution Method
#
# This method uses unpooling and deconvolutional method to transfer the obtained feature map back to the original pixel space, which helps us to see which specific feature map is sensible to what kind of patterns. Here deconvolution is not inverse operation, but the transpose of convolutional layer.
#
# ### (2) Deep Dream
#
# This method aims to find the input images that maximize certain features inside the neural network. This will show us what images the neural network likes to see the most. It essentially performs optimization with gradient ascent. The image is initialized with small random values and is then iteratively updated using the gradient for the given feature with regard to the image.

# %% [markdown]
# Then let us see how these methods perform in different datasets and methods

# %% [markdown]
# # Feature Visulization For MNIST
#
# The MNIST database of handwritten digits has a training set of 55,000 examples, and a test set of 10,000 examples. The digits have been size-normalized and centered in a fixed-size image. It is a good database for people who want to try learning techniques and pattern recognition methods on real-world data while spending minimal efforts on preprocessing and formatting. Here we construct a 5 layers convolutional neural networks to perform image recognization and then use two methods we've introduced above to do feature visualization.
#
# ## 1. Pre-processing and Model Construction
# ### (1) Load Data and Library

# %%
import tensorflow as tf
import numpy as np
import pickle
from tensorflow.python.platform import gfile
from random import randint
import os
import scipy.misc 
from matplotlib import pyplot as plt
# load the minist dataset
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('../data/mnist', one_hot=True)
# Out:
# Extracting ../data/mnist/train-images-idx3-ubyte.gz
# Extracting ../data/mnist/train-labels-idx1-ubyte.gz
# Extracting ../data/mnist/t10k-images-idx3-ubyte.gz
# Extracting ../data/mnist/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ### (2) Define Helper Functions
#
# Here we define some functions to help us construct CNN and visualize the features

# %%
# This function aims to create the weight variable
def weight_varible(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

# This function aims to create the bias variable
def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# This function aims to construct convolution layer
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

# This function aims to construct the max pooling layer
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

def unpool(value, name='unpool'):
    '''
    This function aims to generate the unpooling layer
    
    parameter
    ---------
    value: A Tensor of shape [b, d0, d1, ..., dn, ch]
    
    return
    ------
    out: A Tensor of shape [b, 2*d0, 2*d1, ..., 2*dn, ch]
    '''
    with tf.name_scope(name) as scope:
        sh = value.get_shape().as_list()
        dim = len(sh[1:-1])
        out = (tf.reshape(value, [-1] + sh[-dim:]))
        for i in range(dim, 0, -1):
            out = tf.concat([out, out],i)
        out_size = [-1] + [s * 2 for s in sh[1:-1]] + [sh[-1]]
        out = tf.reshape(out, out_size, name=scope)
    return out

def plot_images(num_row, num_col, images, smooth=True):
    '''
    This function aims to make plots. 
    
    Parameter
    ---------
    num_row: The number of row of the subplots
    num_col: The number of column of the subplots
    images: A numpy array has the shape [i, :, :]. i is the number of picture we have.
    
    Return
    ------
    Show image directly on the notebook
    '''
    
    # Interpolation type.
    if smooth:
        interpolation = 'spline16'
    else:
        interpolation = 'nearest'

    # Create figure with sub-plots.
    fig, axes = plt.subplots(num_row, num_col, figsize = (20,8))

    # Adjust  spacing.
    plt.subplots_adjust(top=0.4, bottom=0.08, left=0.10, right=0.95, hspace=0.5,
                    wspace=0.35)

    # For each entry in the grid.
    for i, ax in enumerate(axes.flat):
        # Get the i'th image and only use the desired pixels.
        img = images[i, :, :]
        
        # Plot the image.
        ax.imshow(img, interpolation=interpolation, cmap='binary')
        ax.set_title('Feature_{}'.format(i+1))

        # Remove ticks.
        ax.set_xticks([])
        ax.set_yticks([])
        
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# ### (3) CNN Model Construction and Training
#
# Here we construct a classical six layers CNN model which contains two convolutional layers; two pooling layers; one fully connected layer and one drop out layer. After 1000 steps, we get a very high test accuracy: **96.26%**

# %%
batchsize = 50
imagesize = 28

sess = tf.InteractiveSession()
# paras
W_conv1 = weight_varible([5, 5, 1, 32])
b_conv1 = bias_variable([32])

# conv layer-1
x = tf.placeholder(tf.float32, [None, 784])
x_image = tf.reshape(x, [-1, 28, 28, 1])

h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

# conv layer-2
W_conv2 = weight_varible([5, 5, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

# full connection
W_fc1 = weight_varible([7 * 7 * 64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 7 * 7 * 64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

# dropout
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# output layer: softmax
W_fc2 = weight_varible([1024, 10])
b_fc2 = bias_variable([10])

logits = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

y_conv = tf.nn.softmax(logits)
y_ = tf.placeholder(tf.float32, [None, 10])

# model training
cross_entropy = -tf.reduce_sum(y_ * tf.log(y_conv))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)

correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

sess.run(tf.global_variables_initializer())


for i in range(1000):
    batch = mnist.train.next_batch(50)

    if i % 100 == 0:
        train_accuacy = accuracy.eval(feed_dict={x: batch[0], y_: batch[1], keep_prob: 1.0})
        ##t.eval() is a shortcut for calling tf.get_default_session().run(t)
        print("step %d, training accuracy %g"%(i, train_accuacy))
    train_step.run(feed_dict = {x: batch[0], y_: batch[1], keep_prob: 0.5})

# accuacy on test
print("test accuracy %g"%(accuracy.eval(feed_dict={x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0})))
# Out:
# step 0, training accuracy 0.12
# step 100, training accuracy 0.9
# step 200, training accuracy 0.88
# step 300, training accuracy 0.88
# step 400, training accuracy 0.98
# step 500, training accuracy 0.98
# step 600, training accuracy 0.96
# step 700, training accuracy 0.96
# step 800, training accuracy 1
# step 900, training accuracy 0.86
# test accuracy 0.9663

# %% [markdown]
# ## 2. Deconvolution Feature Visualization
#
# Here we will use deconvolution method to perform feature visualization.
# ### (1) Reconstruction From The First Convolutional Layer

# %%
# construct unpooling and deconvolutional layer
featuresReLu_1 = tf.placeholder(tf.float32,[None,14,14,32])
unPool_1 = unpool(featuresReLu_1) # unpooling
unReLu_1 = tf.nn.relu(unPool_1)
unBias_1 = unReLu_1
unConv_1 = tf.nn.conv2d_transpose(unBias_1, W_conv1, output_shape=[batchsize,28,28,1] , strides=[1,1,1,1], padding="SAME")

# %%
# Get the feature maps (after pooling) from the first layer 
activations1 = h_pool1.eval(feed_dict={x: mnist.train.next_batch(50)[0], y_: mnist.train.next_batch(50)[1]})
print (activations1.shape)
# Out:
# (50, 14, 14, 32)

# %%
# get every feature map (1, 14, 14, 1) from activations1 then reconstruct the convolution layer
plt.figure(num='CNV1',figsize=(10,8))
for i in range(32):
    isolated = activations1.copy()
    isolated[:,:,:,:i] = 0
    isolated[:,:,:,i+1:] = 0 #These two lines set all other features other than feature i to 0
    #print (isolated.shape)
    totals = np.sum(isolated,axis=(1,2,3))
    best = np.argmax(totals,axis=0) # choose the most obvious image in terms of i feature
    #These two lines are particular for batch of images.
    #That means choose one image from this batch of images which feacture i can judge best.
    #print (totals)
    pixelactive = unConv_1.eval(feed_dict={featuresReLu_1: isolated})
    #print(pixelactive.shape) 
    #shape of every pixelactive is (50, 28, 28, 1) batchsize=50 picsize=28*28 colors=1
    plt.subplot(4,8,i+1) 
    plt.title('Feature_{}'.format(i+1))
    plt.imshow(pixelactive[best,:,:,0],cmap="gray")
    plt.axis('off') 
plt.subplots_adjust(top=0.5, bottom=0.08, left=0.10, right=0.95, hspace=0.5,
                    wspace=0.35)
plt.show()

# %% [markdown]
# It is obvious that the images that restored from the first convolutional layer still keep a very clear pattern to tell us which number this image represent for. But if we see them more carefully, we find that each feature image starts to represent different peculiarity, which means each feature has different functionality to extract the key information. Here are the detailed analysis:
#
# * **Feature Comparison: **
#     1. By looking at these images which have a outline of number 0, we could compare their similarities and differences. Feature 11 has a more clear outline which means this feature has a function to identify the boundary. Also, feature 17 and 25, 26 have a function to identify the shadow inside of the number 0. Finally, even the feture 6 only shows us a vague '0', we could easily see that this feature can identify the boundary shadow which is very important in image recognition.
#     2. With similar analysis as above, for the images that have a outline of number 8, feature 7, 19 could identify different part of the boundary shadow; feature 4 is sensible to the light since it hardly extracts shadow information.
#
# * **Feature Grouping:**
#     1. Boundary Detection Group. Features in this group have a function to detect the boundary of the number: Feature 7,11,13, 17.
#     2. Shadow Detection Group. Features in this group have a function to detect the shadow: Feature 2, 6, 10, 13, 17, 31.
#     3. Light Detection Group. Features in this group are sensible to light: Feature 4, 14, 15.

# %% [markdown]
# ### (2) Reconstruction From The Second Convolutional Layer

# %%
#Get the feature maps from the second convolutional layer
activations2 = h_pool2.eval(feed_dict={x: mnist.train.next_batch(50)[0], y_: mnist.train.next_batch(50)[1]})
print (activations2.shape)
# Out:
# (50, 7, 7, 64)

# %%
#Reconstruction from the layer CNV-2
featuresReLu_2 = tf.placeholder(tf.float32,[None,7,7,64])
unPool_2 = unpool(featuresReLu_2)
unReLu_2 = tf.nn.relu(unPool_2)
unBias_2 = unReLu_2
unBias_2
#unConv = tf.nn.conv2d_transpose(unBias, W_conv1, output_shape=[1,28,28,1] , strides=[1,1,1,1], padding="SAME")
unConv_2 = tf.nn.conv2d_transpose(unBias_2, W_conv2, output_shape=[batchsize,14,14,32] , strides=[1,1,1,1], padding="SAME")
unPool_1 = unpool(unConv_2)
unReLu_1 = tf.nn.relu(unPool_1)
unBias_1 = unReLu_1
unBias_1
#unConv = tf.nn.conv2d_transpose(unBias, W_conv1, output_shape=[1,28,28,1] , strides=[1,1,1,1], padding="SAME")
unConv_1 = tf.nn.conv2d_transpose(unBias_1, W_conv1, output_shape=[batchsize,28,28,1] , strides=[1,1,1,1], padding="SAME")

# %%
#get every feature (1, 14, 14, 1) from activations1 than reconstruct from 
plt.figure(num='CNV2',figsize=(20,8))
for i in range(64):
    isolated = activations2.copy()
    isolated[:,:,:,:i] = 0
    isolated[:,:,:,i+1:] = 0#These two lines set all other features other than feature i to 0
    #print (isolated.shape)
    totals = np.sum(isolated,axis=(1,2,3))
    best = np.argmax(totals,axis=0)
    #These two lines are particular for batch of images.
    #That means choose one image from this batch of images which feacture i can judge best.
    #print (totals)
    pixelactive = unConv_2.eval(feed_dict={featuresReLu_2: isolated})
    #print(pixelactive.shape) 
    #shape of every pixelactive is (50, 28, 28, 1) batchsize=50 picsize=28*28 colors=1
    plt.subplot(4,16,i+1)    
    plt.title('Feature_{}'.format(i+1))
    plt.imshow(pixelactive[best,:,:,0],cmap="gray")
    plt.axis('off') 
plt.subplots_adjust(top=0.5, bottom=0.08, left=0.10, right=0.95, hspace=0.5,
                    wspace=0.35)
plt.show()

# %% [markdown]
# The images restored from the second convolutional layer are much complicated and totally different comparing with the images that restored from the first convolutional layer. That is because by using `relu` and `pooling` more, it is more hard to restore image back to its original appearance; in another word, the deep convolutional layer tries to extract more abstract and summarized features. Here are the detailed analysis:
#
# * **Feature Grouping:**
#     1. Textures Detection Group. Features in this group tend to detect the textures: Feature 7, 8, 12, 15, 16, 20
#     2. Number Detection Group. Features in this group could identify the specific number: Feature 9, 26, 53, 58.
#     3. Edges Detection Group. Features in this group have a function to detect the edges: Feature 27, 31, 58, 60
#     4. Patterns Detection Group. Features in this group have a function to detect the patterns: Feature 39
#     5. Shadow Detection Group. Features in this group try to extract the shadow information: Feature 9, 27, 32

# %% [markdown]
# ## 3. Deep Dream Feature Visualization
#
# Here we use deep dream method to perform feature visualization
# ### (1) Define Helper Function
# The functions below use gradient ascent to maximize certain features inside the neural networks.

# %%
def Deep_Dream_image(conv_layer, feature=0,
                   num_iterations=30):
    """
    This function aims to find an image that maximizes the feature given by the 
    convlution layer and feature number

    Parameter
    ---------
    conv_layer: Tensor that identifying the convolutional layer to
             maximize. If None then use the last fully-connected layer before the softmax output.
    feature: Index into the layer for the feature to maximize.
    
    num_iteration: Number of optimization iterations to perform.
    
    show_progress: Boolean whether to show the progress.
    
    Return
    ------
    image.squeeze(): A numpy array contains the output information 
    
    """

    # Create the loss-function that must be maximized.
    if conv_layer is None:
        
        # The loss-function is just the value of that feature.
        loss = tf.reduce_mean(logits[:, feature])
    else:

        # The loss-function is the average of all the tensor-values for the given feature. 
        loss = tf.reduce_mean(conv_layer[:, :, :, feature])
        
    # Get the gradient for the loss-function with regard to the input image. 
    gradient = tf.gradients(loss, x_image)

    # Use one of the training image as the test image
    image = mnist.train.next_batch(1)[0]
    image = image.reshape((28,28))

    # Perform a number of optimization iterations to find the image that maximizes the loss-function.
    for i in range(num_iterations):
        # Reshape the array so it is a 4-rank tensor.
        img_reshaped = image[np.newaxis,:,:,np.newaxis]
        img_ori = img_reshaped.reshape((-1,784))

        # Create a feed-dict for inputting the image to the graph.
        feed_dict = {keep_prob: 1.0, x: img_ori, x_image: img_reshaped}
       

        # Calculate the predicted class-scores as well as the gradient and the loss-value.
        pred, grad, loss_value = sess.run([y_conv, gradient, loss],
                                             feed_dict=feed_dict)
        
        # Squeeze the dimensionality for the gradient-array. (Back to 28 * 28)
        grad = np.array(grad).squeeze()

        # The gradient now tells us how much we need to change the input image in order to maximize the given feature.

        # Calculate the step-size for updating the image. This step-size was found to give fast convergence.
        step_size = 1.0 / (grad.std() + 1e-8)
        
        # Gradient ascent.
        image += step_size * grad

        # Ensure all pixel-values in the image are between 0 and 1.
        image = np.clip(image, 0.0, 1.0)

    return image.squeeze()

# finds the images that maximize all the features of a layer
def Deep_Dream_images(conv_layer=None, num_iterations=30):
    """
    This functions aims to find 10 images that maximizes the 10 first features in the layer
    given by the convolution layer.
    
    Parameter
    ---------
    conv_layer : Tensor identifying the convolutional layer to maximize. 
    If None then use the last layer before the softmax output.
    
    num_iterations: Number of optimization iterations to perform.
    
    show_progress: whether or not to show the progress
    """

    # Which layer are we using?
    if conv_layer is None:
        print("Final fully-connected layer before softmax.")
    else:
        print("Layer:", conv_layer.name)

    # Initialize the array of images.
    images = []

    # For each feature do the following.
    for feature in range(int(conv_layer.shape[-1])):
        #print("Optimizing image for feature no.", feature)
        
        # Find the image that maximizes the given feature
        image = Deep_Dream_image(conv_layer=conv_layer, feature=feature,
                               num_iterations=num_iterations)

        # Squeeze the dim of the array.
        image = image.squeeze()

        # Append to the list of images.
        images.append(image)

    # Convert to numpy-array so we can index all dimensions easily.
    images = np.array(images)

    # Plot the images.
    plot_images(num_row = 4, num_col = int(int(conv_layer.shape[-1])/4) ,images=images)

# %% [markdown]
# ### (2) Maximize The Features In First Convolutional Layer
#
# Here we will use the functions we generated above to visualize the feature.

# %%
Deep_Dream_images(h_conv1)
# Out:
# Layer: Relu:0

# %% [markdown]
# We know that Deep Dream Method tries to maximize certain features in our first convolutional layer. So in some sense these images tell us what kind of information each feature wants to extract.
#
# * **Feature Grouping**
#     1. Darkness Detection Group. Features in this group tend to detect darkness: Feature 1,3,5,16,24,25,26,29,30.
#     2. Light Detection Group. Features in this group tend to detect the light: Feature 14, 15.
#     3. Texture Detection Group. Features in this group tend to detect texture information: Feature 2, 9, 22, 27.
#     4. Number Detection Group. Features in this group have a function to identify specific number: Feature 8, 10, 12, 20, 32.
#     5. Boundary Detection Group. Feature in this group have a function to detect the boundary. Feature 7, 11, 13, 17, 28, 31.
#
# Then we then compare these results with our deconvolution output images. We expect to see these features should have consistent function for these images, and we are happy to see that they do have the consistent effect.
#
# Let us then compare the grouping results above with our previous deconvolution output images.

# %% [markdown]
# ![1](fig/MNIST1.jpg)

# %% [markdown]
# * **Method Comparison**
#     1. For features in Darkness Detection Group, we could see the matched images do have more darkness than other images, such as feature 1, 29, 30.
#     2. For features in Light Detection Group, we could see the matched images have a very obvious black-white contrast, which means it do extract a lot of light information.
#     3. For features in Texture Detection Group, we could see the backgroud of the matched images is stripy (Feature 2,9,22,27), so these features do control the texture information extraction.
#     4. For features in Number Detection Group, we could see the matched images also show the same number as the features. So these features have a function to identify specific number.
#     5. For features in Boundary Detection Group, the shadow is very obvious. One more intersting phenomenon is that if the black stripe tends to be horizontal, the shadow will also appear in horizontal level, such as feature 7; If the black stripe tends to be vertical, the shadow will also appear in vertical level, such as feature 11 and 13.
#
# So, we could see, these two method do have some consistency and could give us a very clear way what kind of information our features identify.

# %% [markdown]
# ### (3) Maximize The Features In Second Convolutional Layer

# %%
Deep_Dream_images(h_conv2)
# Out:
# Layer: Relu_1:0

# %% [markdown]
# For the features in the second convolutional layer, it appears to be harder to explain just like in the first method. But we still can find some interesting pattern. And this time, I will directly compare it with our previous deconvolution results to generate some insights. Here are the detailed analysis:
#
# 1. **Texture Analysis**:  we have seen that as the neural networks going deep, the features tend to be more abstract since information has been summarised. In that case, most of the feature will tend to extract more generalized information and texture is one of the most important one. See here most of the features have some stripy textures and most of their matched images will have the same appearance.
# 2. **Pattern Analysis**: Pattern is another important information that deep layer features want to extract. For example if we look at the feature 56, it has a clear pattern. And when we look at the matched image below, it also prove our assumption.
# 3. **Parts Analysis** : Even in the second layer, there are still some features could identify parts of the number information.  For example feature 28, feature 32. So these features have a very strong sense to identify these specific numbers.

# %% [markdown]
# ![2](fig/MNIST2.jpg)
